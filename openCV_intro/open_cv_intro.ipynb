# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_path = 'people.jpg'
img = cv2.imread(image_path)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_detector = cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
face_detection = face_detector.detectMultiScale(img_gray, scaleFactor=1.1)
eye_detection = eye_detector.detectMultiScale(img_gray, scaleFactor=1.1, minNeighbors=10, minSize=(30, 30))

# %%
face_detection
# Out:
# array([[ 923,   58,  147,  147],
#        [ 452,   85,  136,  136],
#        [  69,   79,  162,  162],
#        [ 569,   79,  159,  159],
#        [ 559,  397,  147,  147],
#        [ 226,  127,  146,  146],
#        [ 769,  446,  134,  134],
#        [ 740,  190,  167,  167],
#        [ 404,  229,  143,  143],
#        [1080,  133,  153,  153]], dtype=int32)

# %%
eye_detection
# Out:
# array([[ 303,  163,   42,   42],
#        [ 101,  113,   44,   44],
#        [1109,  171,   39,   39],
#        [ 949,   96,   41,   41],
#        [ 825,  231,   44,   44],
#        [ 577,  433,   46,   46],
#        [ 636,  432,   46,   46],
#        [1159,  172,   45,   45],
#        [ 250,  157,   46,   46],
#        [ 772,  239,   42,   42],
#        [ 153,  124,   45,   45]], dtype=int32)

# %%
for (x, y, w, h) in face_detection:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

for (x, y, w, h) in eye_detection:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
