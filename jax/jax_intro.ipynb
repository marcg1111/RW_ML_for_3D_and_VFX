# %%
import jax.numpy as jnp

# %%
def relu(x):
    return jnp.maximum(0, x)

def softmax(x):
    return jnp.exp(x) / jnp.sum(jnp.exp(x), axis=0)

def cross_entropy(x, y):
    return -jnp.sum(y * jnp.log(x))

# %%
x = jnp.arange(6.0)
print(relu(x))
print(softmax(x))
print(cross_entropy(softmax(x), x))
# Out:
# [0. 1. 2. 3. 4. 5.]
# [0.00426978 0.01160646 0.03154963 0.08576079 0.233122   0.6336913 ]
# 26.8429

# %%
from jax import random

key = random.PRNGKey(0)
key, subkey = random.split(key)
print(subkey)
# Out:
# [ 928981903 3453687069]

# %%
x = random.normal(key, (1_000_000_000_000,))
# %timeit relu(x)
# Out:
# 13.5 μs ± 866 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
from jax import jit

jittered_relu = jit(relu)
a = jittered_relu(x)
# %timeit relu(a)
# Out:
# 13.7 μs ± 818 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
